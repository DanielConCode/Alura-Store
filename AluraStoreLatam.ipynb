# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

# pandas es una librería de Python que te permite trabajar con estructuras de datos tipo tablas

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

# La función read_csv() sirve para leer archivos .csv (Comma Separated Values) y convertirlos automáticamente en un DataFrame de pandas.
# DataFrame → una tabla completa (como una hoja de cálculo).

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# El método head() se usa para ver las primeras filas de un DataFrame. Esto te muestra las primeras 5 filas por defecto pero También se puede especificar cuántas filas deseamos ver agregandolo como parametro de head().
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ## Ingreso total por cada tienda
#
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
'''
Para calcular el total de una columna de un DataFrame, utilizamos la sintaxix dataframe['nombre_columna'].sum()
'''

ingreso1 = float(tienda['Precio'].sum())
ingreso2 = float(tienda2['Precio'].sum())
ingreso3 = float(tienda3['Precio'].sum())
ingreso4 = float(tienda4['Precio'].sum())

ingresos = [ingreso1, ingreso2, ingreso3, ingreso4]

for i in range (0, len(ingresos)):
  print(f'El costo de ingreso de la tienda {i+1} es: {ingresos[i]}')
# Out:
# El costo de ingreso de la tienda 1 es: 1150880400.0
# El costo de ingreso de la tienda 2 es: 1116343500.0
# El costo de ingreso de la tienda 3 es: 1098019600.0
# El costo de ingreso de la tienda 4 es: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
'''
Para obtener la cantidad de productos vendidos por categoria, podemos usar la funcion .value_conts(), este metodo cuenta la cantidad de veces que aparece cada valor único en una columna de un DataFrame o en una Serie.

La sintaxix es similar a la que utilizamos para sumar, dataframe['nombre_columna'].value_conts()
'''

conteoCategoriaTienda1 = tienda['Categoría del Producto'].value_counts()
conteoCategoriaTienda2 = tienda2['Categoría del Producto'].value_counts()
conteoCategoriaTienda3 = tienda3['Categoría del Producto'].value_counts()
conteoCategoriaTienda4 = tienda4['Categoría del Producto'].value_counts()

# %%
'''
Para obtener la categoria mas popular de cada tienda, obtendremos el valor mas repetido, usando .index y .values para crear una lista de tuplas que contendra las categorias mas populares y sus ventas

al obtener el valor con .values, este retornara un int que usa Panda, por lo que lo convertimos a un int normal
'''

categoriaTienda1 = conteoCategoriaTienda1.index[0], int(conteoCategoriaTienda1.values[0])
categoriaTienda2 = conteoCategoriaTienda2.index[0], int(conteoCategoriaTienda2.values[0])
categoriaTienda3 = conteoCategoriaTienda3.index[0], int(conteoCategoriaTienda3.values[0])
categoriaTienda4 = conteoCategoriaTienda4.index[0], int(conteoCategoriaTienda4.values[0])

categoriasPopulares = [categoriaTienda1, categoriaTienda2, categoriaTienda3, categoriaTienda4]

for i in range(0,len(categoriasPopulares)):
  print(f'La categoria mas popular de la tienda {i+1} es {categoriasPopulares[i][0]} con {categoriasPopulares[i][1]} ventas')
# Out:
# La categoria mas popular de la tienda 1 es Muebles con 465 ventas
# La categoria mas popular de la tienda 2 es Muebles con 442 ventas
# La categoria mas popular de la tienda 3 es Muebles con 499 ventas
# La categoria mas popular de la tienda 4 es Muebles con 480 ventas

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
promedio1 = round(float(tienda['Calificación'].sum() / len(tienda['Calificación'])),2)
promedio2 = round(float(tienda2['Calificación'].sum() / len(tienda2['Calificación'])),2)
promedio3 = round(float(tienda3['Calificación'].sum() / len(tienda3['Calificación'])),2)
promedio4 = round(float(tienda4['Calificación'].sum() / len(tienda4['Calificación'])),2)

promediosSatisfaccion = [promedio1, promedio2, promedio4, promedio4]

for i in range(0,len(promediosSatisfaccion)):
  print(f'La calificacion de los clientes para la tienda {i+1} es {promediosSatisfaccion[i]}')
# Out:
# La calificacion de los clientes para la tienda 1 es 3.98
# La calificacion de los clientes para la tienda 2 es 4.04
# La calificacion de los clientes para la tienda 3 es 4.0
# La calificacion de los clientes para la tienda 4 es 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
def obtenerProductosMasVendidos(tienda):
  producto = tienda['Producto'].value_counts()

  return [(producto.index[0], int(producto.values[0])), (producto.index[1], int(producto.values[1])), (producto.index[2], int(producto.values[2])), (producto.index[3], int(producto.values[3])), (producto.index[4], int(producto.values[4]))]

productosMasVendidos = {'Tienda 1': obtenerProductosMasVendidos(tienda),
                        'Tienda 2': obtenerProductosMasVendidos(tienda2),
                        'Tienda 3': obtenerProductosMasVendidos(tienda3),
                        'Tienda 4': obtenerProductosMasVendidos(tienda4)}

print(f'Productos Mas Vendidos: \n')
for i in productosMasVendidos:
  datos = pd.DataFrame(productosMasVendidos[i], columns=['Producto', 'Ventas']) #los datos extraídos de productosVendidos[i] (que es una lista de tuplas). Las tuplas tienen el nombre del producto y las ventas, y luego se asignan las etiquetas 'Producto' y 'Ventas' a las columnas del DataFrame.
  print(f'\n{i}')
  print(datos)
# Out:
# Productos Mas Vendidos:
#
#
# Tienda 1
#            Producto  Ventas
# 0        Microondas      60
# 1     TV LED UHD 4K      60
# 2           Armario      60
# 3  Secadora de ropa      58
# 4     Mesa de noche      56
#
# Tienda 2
#                     Producto  Ventas
# 0  Iniciando en programación      65
# 1                 Microondas      62
# 2                    Batería      61
# 3          Guitarra acústica      58
# 4                  Pandereta      58
#
# Tienda 3
#           Producto  Ventas
# 0    Kit de bancas      57
# 1  Mesa de comedor      56
# 2        Cama king      56
# 3     Set de ollas      55
# 4    Mesa de noche      55
#
# Tienda 4
#                     Producto  Ventas
# 0                   Cama box      62
# 1                 Cubertería      59
# 2    Dashboards con Power BI      56
# 3                  Cama king      56
# 4  Carrito de control remoto      55

# %%
def obtenerProductosMenosVendidos(tienda):
  producto = tienda['Producto'].value_counts()

  return [(producto.index[-1], int(producto.values[-1])), (producto.index[-2], int(producto.values[-2])), (producto.index[-3], int(producto.values[-3])), (producto.index[-4], int(producto.values[-4])), (producto.index[-5], int(producto.values[-5]))]

productosMenosVendidos = {'Tienda 1': obtenerProductosMenosVendidos(tienda),
                        'Tienda 2': obtenerProductosMenosVendidos(tienda2),
                        'Tienda 3': obtenerProductosMenosVendidos(tienda3),
                        'Tienda 4': obtenerProductosMenosVendidos(tienda4)}

print(f'Productos Menos Vendidos: \n')
for i in productosMenosVendidos:
  datos = pd.DataFrame(productosMenosVendidos[i], columns=['Producto', 'Ventas'])
  print(f'\n{i}')
  print(datos)
# Out:
# Productos Menos Vendidos:
#
#
# Tienda 1
#                       Producto  Ventas
# 0                 Celular ABXY      33
# 1    Auriculares con micrófono      33
# 2              Olla de presión      35
# 3                    Pandereta      36
# 4  Ciencia de datos con Python      39
#
# Tienda 2
#           Producto  Ventas
# 0    Juego de mesa      32
# 1        Impresora      34
# 2  Mesa de comedor      34
# 3           Sillón      35
# 4      Auriculares      37
#
# Tienda 3
#                   Producto  Ventas
# 0  Bloques de construcción      35
# 1               Microondas      36
# 2                  Mochila      36
# 3             Set de vasos      36
# 4       Guitarra eléctrica      38
#
# Tienda 4
#                       Producto  Ventas
# 0           Guitarra eléctrica      33
# 1                      Armario      34
# 2            Guitarra acústica      37
# 3  Ciencia de datos con Python      38
# 4                 Refrigerador      38

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
costoEnvio1 = float(tienda['Costo de envío'].sum() / len(tienda['Costo de envío']))
costoEnvio2 = float(tienda2['Costo de envío'].sum() / len(tienda['Costo de envío']))
costoEnvio3 = float(tienda3['Costo de envío'].sum() / len(tienda['Costo de envío']))
costoEnvio4 = float(tienda4['Costo de envío'].sum() / len(tienda['Costo de envío']))

costosDeEnvio = [costoEnvio1, costoEnvio2, costoEnvio3, costoEnvio4]

for i in range(0, len(costosDeEnvio)):
  print(f'Los costos de envio para la tienda {i+1} son {costosDeEnvio[i]:.2f}')
# Out:
# Los costos de envio para la tienda 1 son 26018.61
# Los costos de envio para la tienda 2 son 25216.24
# Los costos de envio para la tienda 3 son 24805.68
# Los costos de envio para la tienda 4 son 23449.51

# %% [markdown]
# # **Visualizacion de graficos**

# %% [markdown]
# Después de realizar los análisis, es hora de transformar sus resultados en visualizaciones que le ayuden a comprender mejor los patrones y los insights encontrados.
#
# De acuerdo con funciones que haya creado, le recomendamos que genere al menos tres gráficos. Estos gráficos deben ser de diferentes tipos (como barras, líneas, dispersión, entre otros) para presentar una visión completa de los datos.
#
# Recuerde que los gráficos deben complementar el análisis realizado, resaltando los puntos más relevantes, como los ingresos de la tienda, la distribución de categorías de productos, las opiniones de los clientes, los productos más vendidos y/o los costes de envío.
#
# No es necesario mostrar una visualización en cada paso, pero al final del análisis debes generar los gráficos que consideres más útiles para interpretar los datos.

# %%
# pyplot es módulo dentro de matplotlib para crear y controlar gráficas como si estuvieras "dibujando paso a paso".

import matplotlib.pyplot as plt

# Creamos una lista con las etiquetas de los nombres de las tiendas para poder mostrar los graficos
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# %% [markdown]
# ## Análisis de facturación

# %%
colores = ['red', 'orange', 'green', 'blue'] # Paleta de colores de las barras
plt.bar(tiendas, ingresos, color = colores) # Grafico de barras
plt.title("Ingreso total por cada tienda")
plt.ylabel("Ingresos")
plt.ylim(1000000000, 1175000000)
plt.yticks(ingresos)
plt.grid(True, axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ## Calificación promedio de la tienda

# %%
plt.plot(tiendas, promediosSatisfaccion) # Grafico de líneas
plt.title('Satisfacción al Cliente')
plt.ylabel('Estrellas')
plt.yticks(promediosSatisfaccion)
plt.grid(True, axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ## Envío promedio por tienda

# %%
'''
Grafico de pastel, para este las propiedades van dentro del mismo .pie(), labels indica la etiqueta de cada porcion, y autopct indica le porcentaje automatico

La sintaxix de autopct es:
autopct = '%1.#f%%', el primer y ultimo % simbolizan el formato, # el numero de decimales deseados, la f indicando el formateo y un % antes del que cierra la sintaxix para que se muestre el simbolo de %

No olvidar las comillas al inicio y al final
'''

plt.pie(costosDeEnvio, labels=tiendas, autopct='%1.2f%%')
plt.title('Porcentaje de Costos de Envio')
plt.show()

# %% [markdown]
# ##Ventas por categoría

# %%
categorias = list(conteoCategoriaTienda1.index)

conteo1 =  list(conteoCategoriaTienda1)
conteo2 =  list(conteoCategoriaTienda2)
conteo3 =  list(conteoCategoriaTienda3)
conteo4 =  list(conteoCategoriaTienda4)

import matplotlib.pyplot as plt
import numpy as np # numpy es una libreria que usamos para trabajar listar y numeros

ejex = np.arange(len(categorias)) # arange crea un array con la secuencia de numeros empezando de 0 a la cantidad que ingresemos menos una, en este caso la cantidad de elementos en 'categorias', menos uno
ancho = 0.1 # declaramos un ancho para las barras del grafico

fix, ax = plt.subplots(figsize=(20, 10)) # Crea la figura y los ejes, con figsize=(x, y) determino los tamaños que deseo asignar a los ejes x y y

# ax.bar() crea una barra, la sintaxix es bar(posicion, datos, widht=ancho_de_barra, etiqueta)
ax.bar(ejex-ancho*2, conteo1, width=ancho, label='Tienda 1')
ax.bar(ejex-ancho, conteo2, width=ancho, label='Tienda 2')
ax.bar(ejex, conteo3, width=ancho, label = 'Tienda 3')
ax.bar(ejex+ancho, conteo4, width=ancho, label='Tienda 4')

# Creamos 4 barras, una para cada tienda, cambiamos la posicion de cada una de ellas para que no aparezcan todas en la misma posicion y sean todas la barras visibles

# Para colocar las categorias como etiqueta de cada barra
ax.set_xticks(ejex) #ax.set_xticks(posiciones) para setear las posiciones que las etiquetas tomaran
ax.set_xticklabels(categorias) #ax.set_xticklabels(nombres) para setear las etiquetas en las posiciones que elegimos

ax.set_ylim(125,525) # determina los limites del eje y para visualizar mejor los datos y comparar
ax.set_yticks([150,175,200,225,250,275,300,325,350,375,400,425,450,475,500])

ax.grid(True, axis='y') # Permitimos que la linea de los ejes x sea visible con .grid(True, axis='eje paralelo a las lineas que deseamos mostrar(x o y)')
ax.legend() # Muestra la leyenda del grafico que seteamos en cada una de las barras
plt.show()

# %% [markdown]
# # Reporte

# %% [markdown]
# ##**Introduccion**
#
# El proposito del presente informe tiene el objetivo de analizar cual de las cuatro tiendas en cuestion seria la mas recomendada en vender con el fin de montar un nuevo negocio, los resultados han sido tomado en base a diversos factores que justifican las fortalezas y debilidades de cada una de las sucursales.
#
# Los principales puntos tomados en cuenta para el analisis fueron:
#
# *   Los ingresos totales de las tiendas.
# *   Las categorías de productos más y menos vendidas.
# *   Las calificaciones promedio de los clientes por tienda.
# *   Los productos más y menos vendidos.
# *   El coste de envío promedio para cada tienda.

# %% [markdown]
# ##**Analisis**
# ---
# ##### **Los ingresos totales de las tiendas**
#
# Despues de analizar los ingresos totales de cada tienda, llegamos a la conclusion que la Tienda 1 significa la mayor cantidad de ingresos, mientras que la Tienda 4 se posiciona como la de menor ingresos, y al menos tomando en cuenta la cantidad de ingresos la mas favorable para vender, claro sin tomar en cuenta los demas puntos.
#
# ---
#
# ##### **Las categorías de productos más y menos vendidas.**
#
# En principio, la categoria de productos podria no considerarse como un factor determinante de primeras impresiones, pero al analizar los datos, podemos concluir que la categoria con mas ventas es Muebles, por lo que la tienda con menor venta en la categoria muebles es la Tienda 2, por lo que en esta categoria, esta seria la opcion mas accesible para venta. De igual manera en la categoria de menor ventas, la tienda 2 es la que tiene una mayor cantidad de ventas con respectos a las demas tiendas.
#
# ---
#
# ##### **Las calificaciones promedio de los clientes por tienda.**
#
# El rango de puntuacion en las encuestas de satisfaccion al cliente muestra que la tienda 1 es la de menor puntuacion con respecto a las demas tiendas, mientras que la tienda 2 es la de mayor aprobacion de parte del publico. Esto indica que si bien la tienda 2 no tiene las ventas suficientes de la categoria con mayor ventas entre todas las tiendas, esta posee la aprobacion del publico.
#
# Un dato a destacar es que las tiendas 3 y 4 posee la misma calificacion en satisfaccion al cliente.
#
# ---
#
# ##### **Los productos más y menos vendidos.**
#
# Se analizó los 5 productos con mayor y menos ventas de cada tienda, y podemos concluir que los productos con mayor ventas de la tienda 2, que es la tienda con la mayor calificacion de aprobacion de los clientes, son precisamente instrumentos musicales, e inclusive el de mayor ventas es Iniciando en programacion.
#
# Analizando los de menor ventas en las otras tiendas, podemos deducir que la tienda 4 vende menos articulos que son los mas vendidos para la tienda 2, como por ejemplo  Guitarra eléctrica, Guitarra acústica y Ciencia de datos con Python, productos que de venderse en la tienda 2 muy probablemente se venderian mas.
#
# Esto podria significar que el publico de la tienda 4 tiene un interes diferente al de resto de tiendas, lo que refleja la diferencia en el numero de ventas de los productos mas demandados.
#
# ---
#
# ##### **El coste de envío promedio para cada tienda**
#
# De acuerdo al analisis de costos de envio para cada tienda, las tiendas 1 y 2 son las que implican un mayor costo de envio, mientras que las tiendas 3 y 4 implican un menor costo, muy probablemente debido a que estas ultimas tienen una menor cantidad de ingresos, lo que reflejaria una menor cantidad de ventas.

# %% [markdown]
# ##**Conclusion**
#
# Basandonos en todos los factores al momento de tomar una decision con respecto a cual tienda seria la mas conveniente para vender, podemos deducir que las tiendas 1 y 2 no serian claramente una opcion, la tienda 1 significa la mayor cantidad de ingresos, a pesar de que implica un mayor porcentaje de costo de envios, muy probablemente debido a que la categoria de producto mas vendida es muebles y tenga mucho que ver en el porcentaje de costo de envios.
#
# La tienda 2 es la de mayor aprobacion para el publico, y la segunda en el numero de ingresos. Pese a su numero de ventas es mas bajo en las principales categorias con respecto a las demas tiendas, al parecer los productos vendidos en esta tienda son efectivos y se puede ver reflejado en la satisfaccion al cliente, tambien tendria mucho que ver el tipo de servicio, pero la tienda 2 parece funcionar muy bien.
#
# La tienda 1 al tener la mayor cantidad de ingresos, pero la menor calificacion de todas, una recomendacion que podriamos dar al cliente es verificar la razon por que se obtiene una menor puntuacion de parte de los clientes, ¿Es el servicio lo que necesita mejorar o algo relacionado con los productos?, sin embargo a pesar de tener la peor calificacion de parte del publico, esta sigue siendo la de mayor ingresos, logicamente reflejado en el mayor porcentaje de costo de envios
#
# Podemos concluir, que las 4 tiendas tienen numeros bastante similares, pero seria mas acertado vender la tienda 3 o 4 debido a los puntos mencionados antes. En mi opinion, la tienda 4 podria ser mejor opcion sobre la tienda 3 ya que la tienda 3 presenta un muy buen equilibrio y balance entre todas las tiendas, como por ejemplo un equlibrio entre ingresos-costos de envio, una califiacion intermedia con respecto a las demas, y posee ventas muy equilibradas por categoria con respecto a las demas tiendas.
